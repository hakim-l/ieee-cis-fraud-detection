# %% [markdown]
# # Import CONFIG

# %%
import os
from pathlib import Path

project_root = Path(__file__).parent.resolve()
# Path(os.curdir).resolve()
# Out:
# PosixPath('/home/laenra/projects/ieee-cis-fraud-detection/notebooks')
