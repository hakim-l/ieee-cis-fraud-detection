# %% [markdown]
# # Project settings

# %%
import os
from pathlib import Path

project_root = Path(os.getcwd()).parents[1].resolve()
Path(project_root).resolve()
os.chdir(project_root)

# %%
import pandas as pd
from src import config

# %% [markdown]
# # Initiate dataset

# %%
from src.dataset.dask_dataset import DaskDataset

# %%
transactions_train= DaskDataset(
    config.INTERIM_DATA_DIR / 'train/transactions'
)

# %%
for col in transactions_train.columns:
    print(f"Column: {col.column_name}, Type: {type(col).__name__}")
# Out:
# Column: TransactionID, Type: NumericColumn
# Column: isFraud, Type: NumericColumn
# Column: TransactionDT, Type: NumericColumn
# Column: TransactionAmt, Type: NumericColumn
# Column: ProductCD, Type: CategoricalColumn
# Column: card1, Type: NumericColumn
# Column: card2, Type: NumericColumn
# Column: card3, Type: NumericColumn
# Column: card4, Type: CategoricalColumn
# Column: card5, Type: NumericColumn
# Column: card6, Type: CategoricalColumn
# Column: addr1, Type: NumericColumn
# Column: addr2, Type: NumericColumn
# Column: dist1, Type: NumericColumn
# Column: dist2, Type: NumericColumn
# Column: P_emaildomain, Type: CategoricalColumn
# Column: R_emaildomain, Type: CategoricalColumn
# Column: C1, Type: NumericColumn
# Column: C2, Type: NumericColumn
# Column: C3, Type: NumericColumn
# Column: C4, Type: NumericColumn
# Column: C5, Type: NumericColumn
# Column: C6, Type: NumericColumn
# Column: C7, Type: NumericColumn
# Column: C8, Type: NumericColumn
# ...

# %%
transactions_train
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 transactions_train
#
# NameError: name 'transactions_train' is not defined
